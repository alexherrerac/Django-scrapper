# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import re
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Alex\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def porcentajeClases(output):
    percent = output.value_counts() 
    clase1 = (percent[0] * 100) / (percent[0] + percent[1])
    clase2 = (percent[1] * 100) / (percent[0] + percent[1])
    return (clase1, clase2)

# %%
#Se importan los datos

person = pd.read_csv("C:\\Users\\Alex\\Documents\\scrapy\\finality.csv")
person.columns = ["Nombre", "Universidad", "Profesion", "Ciudad", "Cliente"]
person.head()
# Out:
#                                Nombre  \
# 0          jairo Ricardo Mora Delgado
# 1       Alexander Luan Naranjo Ladino
# 2          jairo Ricardo Mora Delgado
# 3          jairo Ricardo Mora Delgado
# 4       Juan Camilo Gutiérrez Meneses
# 5       Camilo Andrey Bonilla Meneses
# 6       juan Camilo Fernández Salazar
# 7   Carlos Alberto Ceballos Cifuentes
# 8       Jorge Andrés Pulgarín Giraldo
# 9   Carlos Alberto Ceballos Cifuentes
# 10         Mario Alberto Jurado Eraso
# 11         Mario Alberto Jurado Eraso
# 12     Victoria Eugenia Batero Correa
# 13               Marco Antonio Macana
# 14            Liliana Sánchez Ramírez
# 15            Liliana Sánchez Ramírez
# 16      Wilmar Dubian Lince Bohórquez
# 17       Sandra Patricia Rojas Berrío
# 18            Liliana Sánchez Ramírez
# 19         Mario Alberto Jurado Eraso
# 20        Paula Johana Cuaical Garcia
# 21      Xiomara Mayerli Macias Mendez
# 22               ALEJANDRO DÍAZ LLANO
# 23           ALEJANDRO DELGADO ACOSTA
# 24           ALEJANDRO DELGADO ACOSTA
# 25               ALEJANDRO LÓPEZ LEÓN
# 26         ALEJANDRO MONCADA BETANCUR
# 27         ALEJANDRO MONCADA BETANCUR
# 28           ALEJANDRO SERRANO SIERRA
# 29     ALEX ENRIQUE SARMIENTO CAMARGO
# 30       ALEX FERNANDO BARBOSA PINZON
# 31          ALEX JAIRSINO PEREA OLAVE
# 32      Alexander Luan Naranjo Ladino
#
#                                        Universidad  \
# 0                           Universidad del Tolima
# 1                                      Universidad
# 2                             Universidad Nacional
# 3                            Universidad Javeriana
# 4                           Universidad del Tolima
# 5                           Universidad del Tolima
# 6                           Universidad del Tolima
# 7                             Universidad Nacional
# 8                             Universidad Nacional
# 9                                      Universidad
# 10                            Universidad Nacional
# 11                                     Universidad
# 12              Universidad Tecnologica de Pereira
# 13                                     Universidad
# 14                            Universidad Católica
# 15                           Universidad Javeriana
# 16                        Universidad de Antioquia
# 17                           Universidad Javeriana
# 18                    Universidad Nacional Abierta
# 19                               Universidad Libre
# 20  Universidad Distrital Francisco José de Caldas
# 21  Universidad Distrital Francisco José de Caldas
# 22              Universidad Tecnologica de Pereira
# 23  Universidad Distrital Francisco José de Caldas
# 24                                     Universidad
# 25                               Universidad Libre
# 26                            Universidad Nacional
# 27                                     Universidad
# 28                           Universidad Javeriana
# 29                                     Universidad
# 30                                     Universidad
# 31                                     Universidad
# 32                      Politécnico Grancolombiano
#
#                                             Profesion    Ciudad Cliente
# 0                                            Pregrado    Ibagué      Si
# 1       HOSPITAL UNIVERSITARIO DE LA SAMARITANA H U S  Colombia      No
# 2   Revista de la Facultad de Medicina Veterinaria...    Bogotá      Si
# 3                         Cuadernos de Administración    Bogotá      Si
# 4                                            Pregrado    Ibagué      No
# 5                                            Pregrado    Ibagué      No
# 6                                            Pregrado    Ibagué      Si
# 7                    Departamento de Ingeniería Civil    Bogotá      Si
# 8                      Departamento de Administración    Bogotá      Si
# 9                                        Investigador  Colombia      Si
# 10                                     Sede Manizales    Bogotá      No
# 11                         UNIVERSIDAD MARIANA UNIMAR  Colombia      No
# 12                              Ingenieria Industrial   Pereira      No
# 13                       UNIVERSIDAD SANTIAGO DE CALI  Colombia      Si
# 14                             Maestría en Psicología    Bogotá      No
# 15              Especialización en Psicología Clínica    Bogotá      No
# 16          Artículos de Revista en Ciencias Sociales  Medellin      Si
# 17                        Cuadernos de Administración    Bogotá      Si
# 18                                             Libros    Bogotá      No
# 19                                           Pregrado    Bogotá      No
# 20  Licenciatura en Educación Básica con Énfasis e...    Bogotá      No
# 21                   Ingeniería en Telecomunicaciones    Bogotá      Si
# 22               Licenciatura en Matemáticas y Física   Pereira      No
# 23                           Licenciatura en Biología    Bogotá      No
# 24                                       Investigador  Colombia      No
# 25                                      Libre Empresa    Bogotá      Si
# 26                     Departamento de Administración    Bogotá      Si
# 27  GRUPO DE INVESTIGACION DISENO Y DESARROLLO APL...  Colombia      Si
# 28                                       Arquitectura    Bogotá      Si
# 29        DIRECCION DE IMPUESTOS Y ADUANAS NACIONALES  Colombia      Si
# 30                                       Investigador  Colombia      Si
# 31                     SERVIO NACIONAL DE APRENDIZAJE  Colombia      No
# 32             Especialización en Gestión Empresarial    Bogotá      Si

# %%
#Exploración y preprocesamiento de los datos

print('Tamaño del dataset')
print('Número de ejemplos: {}'.format(person.shape[0]))
print('Número de características: {}'.format(person.shape[1]))
# Out:
# Tamaño del dataset
# Número de ejemplos: 33
# Número de características: 5

# %%
#Balance de los datos(target) en el dataset

print('Número de clientes y no clientes: ')
print(person['Cliente'].value_counts())
# Out:
# Número de clientes y no clientes:
# Si    18
# No    15
# Name: Cliente, dtype: int64

# %%
[nocliente, cliente] = porcentajeClases(person['Cliente'])
print('Porcentaje de personas no clientes: {}%'.format(nocliente))
print('Porcentaje de personas cliente: {}%'.format(cliente))
# Out:
# Porcentaje de personas no clientes: 54.54545454545455%
# Porcentaje de personas cliente: 45.45454545454545%

# %%
#Limpieza de los textos

from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
#Se convierten las profesiones a minúsculas
person['Profesion'] = person.Profesion.map(lambda x: x.lower())
#Se quitan los signos de puntuación
person['Profesion'] = person.Profesion.replace('[^\w\s]','')
#Se eliminan los números
person['Profesion'] = [re.sub('[0-9]', '', i) for i in person['Profesion']]
#Se hace la tokenización
person['Profesion'] = person['Profesion'].apply(nltk.word_tokenize)
nltk_words = list(stopwords.words('spanish'))
#Lista de "stopwords" en español
for i in range(0,len(person)):
    person['Profesion'][i] = [w for w in person['Profesion'][i] if w not in nltk_words]
#Se convierte la lista de palabras en un string separado por espacios
person['Profesion'] = person['Profesion'].apply(lambda x: ' '.join(x))

# %%
#Se verifican los cambios
person.head()
# Out:
#                                Nombre  \
# 0          jairo Ricardo Mora Delgado
# 1       Alexander Luan Naranjo Ladino
# 2          jairo Ricardo Mora Delgado
# 3          jairo Ricardo Mora Delgado
# 4       Juan Camilo Gutiérrez Meneses
# 5       Camilo Andrey Bonilla Meneses
# 6       juan Camilo Fernández Salazar
# 7   Carlos Alberto Ceballos Cifuentes
# 8       Jorge Andrés Pulgarín Giraldo
# 9   Carlos Alberto Ceballos Cifuentes
# 10         Mario Alberto Jurado Eraso
# 11         Mario Alberto Jurado Eraso
# 12     Victoria Eugenia Batero Correa
# 13               Marco Antonio Macana
# 14            Liliana Sánchez Ramírez
# 15            Liliana Sánchez Ramírez
# 16      Wilmar Dubian Lince Bohórquez
# 17       Sandra Patricia Rojas Berrío
# 18            Liliana Sánchez Ramírez
# 19         Mario Alberto Jurado Eraso
# 20        Paula Johana Cuaical Garcia
# 21      Xiomara Mayerli Macias Mendez
# 22               ALEJANDRO DÍAZ LLANO
# 23           ALEJANDRO DELGADO ACOSTA
# 24           ALEJANDRO DELGADO ACOSTA
# 25               ALEJANDRO LÓPEZ LEÓN
# 26         ALEJANDRO MONCADA BETANCUR
# 27         ALEJANDRO MONCADA BETANCUR
# 28           ALEJANDRO SERRANO SIERRA
# 29     ALEX ENRIQUE SARMIENTO CAMARGO
# 30       ALEX FERNANDO BARBOSA PINZON
# 31          ALEX JAIRSINO PEREA OLAVE
# 32      Alexander Luan Naranjo Ladino
#
#                                        Universidad  \
# 0                           Universidad del Tolima
# 1                                      Universidad
# 2                             Universidad Nacional
# 3                            Universidad Javeriana
# 4                           Universidad del Tolima
# 5                           Universidad del Tolima
# 6                           Universidad del Tolima
# 7                             Universidad Nacional
# 8                             Universidad Nacional
# 9                                      Universidad
# 10                            Universidad Nacional
# 11                                     Universidad
# 12              Universidad Tecnologica de Pereira
# 13                                     Universidad
# 14                            Universidad Católica
# 15                           Universidad Javeriana
# 16                        Universidad de Antioquia
# 17                           Universidad Javeriana
# 18                    Universidad Nacional Abierta
# 19                               Universidad Libre
# 20  Universidad Distrital Francisco José de Caldas
# 21  Universidad Distrital Francisco José de Caldas
# 22              Universidad Tecnologica de Pereira
# 23  Universidad Distrital Francisco José de Caldas
# 24                                     Universidad
# 25                               Universidad Libre
# 26                            Universidad Nacional
# 27                                     Universidad
# 28                           Universidad Javeriana
# 29                                     Universidad
# 30                                     Universidad
# 31                                     Universidad
# 32                      Politécnico Grancolombiano
#
#                                             Profesion    Ciudad Cliente
# 0                                            pregrado    Ibagué      Si
# 1             hospital universitario samaritana h u s  Colombia      No
# 2     revista facultad medicina veterinaria zootecnia    Bogotá      Si
# 3                            cuadernos administración    Bogotá      Si
# 4                                            pregrado    Ibagué      No
# 5                                            pregrado    Ibagué      No
# 6                                            pregrado    Ibagué      Si
# 7                       departamento ingeniería civil    Bogotá      Si
# 8                         departamento administración    Bogotá      Si
# 9                                        investigador  Colombia      Si
# 10                                     sede manizales    Bogotá      No
# 11                         universidad mariana unimar  Colombia      No
# 12                              ingenieria industrial   Pereira      No
# 13                          universidad santiago cali  Colombia      Si
# 14                                maestría psicología    Bogotá      No
# 15                 especialización psicología clínica    Bogotá      No
# 16                artículos revista ciencias sociales  Medellin      Si
# 17                           cuadernos administración    Bogotá      Si
# 18                                             libros    Bogotá      No
# 19                                           pregrado    Bogotá      No
# 20  licenciatura educación básica énfasis educació...    Bogotá      No
# 21                      ingeniería telecomunicaciones    Bogotá      Si
# 22                    licenciatura matemáticas física   Pereira      No
# 23                              licenciatura biología    Bogotá      No
# 24                                       investigador  Colombia      No
# 25                                      libre empresa    Bogotá      Si
# 26                        departamento administración    Bogotá      Si
# 27  grupo investigacion diseno desarrollo aplicado...  Colombia      Si
# 28                                       arquitectura    Bogotá      Si
# 29             direccion impuestos aduanas nacionales  Colombia      Si
# 30                                       investigador  Colombia      Si
# 31                        servio nacional aprendizaje  Colombia      No
# 32                especialización gestión empresarial    Bogotá      Si

# %%
#Creación del espacio vectorial
from sklearn.feature_extraction.text import  CountVectorizer
count_vect = CountVectorizer()

#Se separan los datos del dataset
y = person["Cliente"]
X = person.drop(columns=["Nombre", "Cliente"])

bagofWords = count_vect.fit_transform(person['Profesion'])

print('Tamaño del modelo de espacio vectorial con todas las palabras: ')
print(bagofWords.shape)
# Out:
# Tamaño del modelo de espacio vectorial con todas las palabras:
# (33, 59)

# %%
# count = CountVectorizer()
# from sklearn.compose import make_column_transformer
# ct = make_column_transformer((count, person['Profesion']), (count, person['Universidad']))
# ct.fit_transform(x)

# %%
import joblib
joblib.dump(count_vect, "bagof.joblib")
# Out:
# ['bagof.joblib']

# %%
#Separación del dataset en un conjunto de entrenamiento y de prueba
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(bagofWords, y, test_size=0.3, random_state=42)

# %%
[nocliente, cliente] = porcentajeClases(y_train)
print('\nPorcentaje de personas no clientes en el conjunto de entrenamiento: {}%'.format(nocliente))
print('Porcentaje de clientes en el conjunto de entrenamiento: {}%'.format(cliente))

[nocliente, cliente] = porcentajeClases(y_test)
print('\nPorcentaje de personas no clientes en el conjunto de prueba: {}%'.format(nocliente))
print('Porcentaje de clientes en el conjunto de prueba: {}%'.format(cliente))
# Out:
# Porcentaje de personas no clientes en el conjunto de entrenamiento: 52.17391304347826%
# Porcentaje de clientes en el conjunto de entrenamiento: 47.82608695652174%
#
# Porcentaje de personas no clientes en el conjunto de prueba: 60.0%
# Porcentaje de clientes en el conjunto de prueba: 40.0%

# %%
#Creación del modelo NB
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb = mnb.fit(X_train, y_train)

# %%
#Guardar modelo en joblib
import joblib
joblib.dump(mnb, "guardar_prueba.joblib")
# Out:
# ['guardar_prueba.joblib']

# %%
#Evaluación del modelo y Precisión
from sklearn.metrics import classification_report, accuracy_score
y_pred = mnb.predict(X_train)
train_accuracy = accuracy_score(y_train, y_pred)
print('\nPrecisión en el conjunto de entrenamiento mnb: {}'.format(train_accuracy))

y_pred = mnb.predict(X_test)
test_accuracy = accuracy_score(y_test, y_pred)
print('Precisión en el conjunto de prueba mnb: {}'.format(test_accuracy))
# Out:
# Precisión en el conjunto de entrenamiento mnb: 0.9130434782608695
# Precisión en el conjunto de prueba mnb: 0.8

# %%
import joblib
model = joblib.load('guardar_prueba.joblib')
bagof = joblib.load('bagof.joblib')

# %%
prueba = "Ingeniería en Telecomunicaciones"
prueba1 = bagof.transform([prueba])

# %%
j_pred = model.predict(prueba1)
j_pred
# Out:
# array(['Si'], dtype='<U2')
